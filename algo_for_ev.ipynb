# %%
import pandas as pd

# %%
df = pd.read_csv("Cleaned_EV_Data.csv")

# %%
df.head()
# Out:
#    VIN (1-10)    County               City State  Postal Code  Model Year  \
# 0  1N4AZ0CP6D      King           Kirkland    WA      98034.0        2013
# 1  5YJ3E1EC8L    Kitsap  Bainbridge Island    WA      98110.0        2020
# 2  5YJ3E1EBXJ      King            Seattle    WA      98144.0        2018
# 3  ZFAFFAC45R  Thurston               Yelm    WA      98597.0        2024
# 4  5YJYGDEE3L      King               Kent    WA      98030.0        2020
#
#      Make    Model           Electric Vehicle Type  \
# 0  NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 1   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 2   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 3    FIAT     500E  Battery Electric Vehicle (BEV)
# 4   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible            75.0
# 1            Clean Alternative Fuel Vehicle Eligible           308.0
# ...

# %%
df.shape
# Out:
# (59999, 16)

# %%
df.isna().sum()
# Out:
# VIN (1-10)                                           0
# County                                               1
# City                                                 1
# State                                                0
# Postal Code                                          1
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       2
# Legislative District                                 1
# DOL Vehicle ID                                       0
# Vehicle Location                                     1
# Electric Utility                                     1
# 2020 Census Tract                                    1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 59999 entries, 0 to 59998
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         59999 non-null  str
#  1   County                                             59998 non-null  str
#  2   City                                               59998 non-null  str
#  3   State                                              59999 non-null  str
#  4   Postal Code                                        59998 non-null  float64
#  5   Model Year                                         59999 non-null  int64
#  6   Make                                               59999 non-null  str
#  7   Model                                              59999 non-null  str
#  8   Electric Vehicle Type                              59999 non-null  str
# ...

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range  Legislative District  \
# count  59998.000000  59999.000000    59997.000000          59998.000000
# mean   98182.157905   2022.152853       38.965732             32.369879
# std      221.729371      3.027038       77.907658             14.478510
# min    98001.000000   2000.000000        0.000000              1.000000
# 25%    98034.000000   2021.000000        0.000000             21.000000
# 50%    98106.000000   2023.000000        0.000000             36.000000
# 75%    98188.000000   2024.000000       32.000000             45.000000
# max    99403.000000   2027.000000      337.000000             49.000000
#
#        DOL Vehicle ID  2020 Census Tract
# count    5.999900e+04       5.999800e+04
# mean     2.468955e+08       5.303377e+10
# std      6.407520e+07       1.238545e+07
# min      1.028600e+04       5.300396e+10
# 25%      2.235354e+08       5.303301e+10
# 50%      2.629412e+08       5.303302e+10
# ...
